# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np


mylist = [1,2,3]
arr = np.array(mylist)

pd.Series(data=mylist)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
labels = ['a', 'b', 'c']

pd.Series(data=arr, index= labels)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
d = {'a': 1, 'b':2, 'c':3}

# %%
ser1 = pd.Series(data=[1,2,3,4], index=['Ussr','america','India','Germany'])
ser2 = pd.Series(data=[1,2,3,4], index=['Ussr','India','Italy','Germany'])

ser1 + ser2
# Out:
# Germany    8.0
# India      5.0
# Italy      NaN
# Ussr       2.0
# america    NaN
# dtype: float64

# %%
#dataframe

arr = np.random.randn(5,5)
df = pd.DataFrame(data =arr,index = "A B C D E".split(), columns= "V W X Y Z".split())
df
# Out:
#           V         W         X         Y         Z
# A  0.635685 -1.274144 -0.760515  0.256064  0.895807
# B  0.452469 -0.416613  0.014855 -1.682868 -0.680210
# C -1.642752 -0.350907 -0.757391 -0.894117 -0.602150
# D -0.370753 -1.905656  0.117189  0.367429 -1.165129
# E -0.351833  0.176655 -0.333306 -0.628017 -0.008559

# %%
mycol = ["V", "W"]
df[mycol]
# Out:
#           V         W
# A  0.635685 -1.274144
# B  0.452469 -0.416613
# C -1.642752 -0.350907
# D -0.370753 -1.905656
# E -0.351833  0.176655

# %%
df['New'] = df['W'] + df['Y']
df
# Out:
#           V         W         X         Y         Z       New
# A  0.635685 -1.274144 -0.760515  0.256064  0.895807 -1.018081
# B  0.452469 -0.416613  0.014855 -1.682868 -0.680210 -2.099481
# C -1.642752 -0.350907 -0.757391 -0.894117 -0.602150 -1.245025
# D -0.370753 -1.905656  0.117189  0.367429 -1.165129 -1.538228
# E -0.351833  0.176655 -0.333306 -0.628017 -0.008559 -0.451362

# %%
df.drop('New', axis=1)
# Out:
#           V         W         X         Y         Z
# A  0.635685 -1.274144 -0.760515  0.256064  0.895807
# B  0.452469 -0.416613  0.014855 -1.682868 -0.680210
# C -1.642752 -0.350907 -0.757391 -0.894117 -0.602150
# D -0.370753 -1.905656  0.117189  0.367429 -1.165129
# E -0.351833  0.176655 -0.333306 -0.628017 -0.008559

# %%
df
# Out:
#           V         W         X         Y         Z       New
# A  0.635685 -1.274144 -0.760515  0.256064  0.895807 -1.018081
# B  0.452469 -0.416613  0.014855 -1.682868 -0.680210 -2.099481
# C -1.642752 -0.350907 -0.757391 -0.894117 -0.602150 -1.245025
# D -0.370753 -1.905656  0.117189  0.367429 -1.165129 -1.538228
# E -0.351833  0.176655 -0.333306 -0.628017 -0.008559 -0.451362

# %%
df.drop('New', axis=1, inplace=True)
df
# Out:
#           V         W         X         Y         Z
# A  0.635685 -1.274144 -0.760515  0.256064  0.895807
# B  0.452469 -0.416613  0.014855 -1.682868 -0.680210
# C -1.642752 -0.350907 -0.757391 -0.894117 -0.602150
# D -0.370753 -1.905656  0.117189  0.367429 -1.165129
# E -0.351833  0.176655 -0.333306 -0.628017 -0.008559

# %%
df.drop('C')
# Out:
#           V         W         X         Y         Z
# A  0.635685 -1.274144 -0.760515  0.256064  0.895807
# B  0.452469 -0.416613  0.014855 -1.682868 -0.680210
# D -0.370753 -1.905656  0.117189  0.367429 -1.165129
# E -0.351833  0.176655 -0.333306 -0.628017 -0.008559

# %%
df.loc['A']
# Out:
# V    0.635685
# W   -1.274144
# X   -0.760515
# Y    0.256064
# Z    0.895807
# Name: A, dtype: float64

# %%
df.iloc[0]
# Out:
# V    0.635685
# W   -1.274144
# X   -0.760515
# Y    0.256064
# Z    0.895807
# Name: A, dtype: float64

# %%
df.loc[['A', 'E']]
# Out:
#           V         W         X         Y         Z
# A  0.635685 -1.274144 -0.760515  0.256064  0.895807
# E -0.351833  0.176655 -0.333306 -0.628017 -0.008559

# %%
df.iloc[[1,3]]
# Out:
#           V         W         X         Y         Z
# B  0.452469 -0.416613  0.014855 -1.682868 -0.680210
# D -0.370753 -1.905656  0.117189  0.367429 -1.165129

# %%
df>0
# Out:
#        V      W      X      Y      Z
# A   True  False  False   True   True
# B   True  False   True  False  False
# C  False  False  False  False  False
# D  False  False   True   True  False
# E  False   True  False  False  False

# %%
df_bool = df>0

df[df_bool]
# Out:
#           V         W         X         Y         Z
# A  0.635685       NaN       NaN  0.256064  0.895807
# B  0.452469       NaN  0.014855       NaN       NaN
# C       NaN       NaN       NaN       NaN       NaN
# D       NaN       NaN  0.117189  0.367429       NaN
# E       NaN  0.176655       NaN       NaN       NaN

# %%
df[df["V"]>0]['Y'].loc["A"]
# Out:
# 0.25606367870736724

# %%
df[df['W']>0]
# Out:
#           V         W         X         Y         Z
# E -0.351833  0.176655 -0.333306 -0.628017 -0.008559

# %%
cond1 = df['V']>0
cond2 = df['Y']>0

df[(cond1) & (cond2)]
# Out:
#           V         W         X         Y         Z
# A  0.635685 -1.274144 -0.760515  0.256064  0.895807

# %%
df.reset_index()
# Out:
#   index         V         W         X         Y         Z
# 0     A  0.635685 -1.274144 -0.760515  0.256064  0.895807
# 1     B  0.452469 -0.416613  0.014855 -1.682868 -0.680210
# 2     C -1.642752 -0.350907 -0.757391 -0.894117 -0.602150
# 3     D -0.370753 -1.905656  0.117189  0.367429 -1.165129
# 4     E -0.351833  0.176655 -0.333306 -0.628017 -0.008559

# %%
df['states'] = 'aw in rus chi, ussr'.split()

# %%
df
# Out:
#           V         W         X         Y         Z states
# A  0.635685 -1.274144 -0.760515  0.256064  0.895807     aw
# B  0.452469 -0.416613  0.014855 -1.682868 -0.680210     in
# C -1.642752 -0.350907 -0.757391 -0.894117 -0.602150    rus
# D -0.370753 -1.905656  0.117189  0.367429 -1.165129   chi,
# E -0.351833  0.176655 -0.333306 -0.628017 -0.008559   ussr

# %%
df.set_index('states')
# Out:
#                V         W         X         Y         Z
# states
# aw      0.635685 -1.274144 -0.760515  0.256064  0.895807
# in      0.452469 -0.416613  0.014855 -1.682868 -0.680210
# rus    -1.642752 -0.350907 -0.757391 -0.894117 -0.602150
# chi,   -0.370753 -1.905656  0.117189  0.367429 -1.165129
# ussr   -0.351833  0.176655 -0.333306 -0.628017 -0.008559

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, A to E
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V       5 non-null      float64
#  1   W       5 non-null      float64
#  2   X       5 non-null      float64
#  3   Y       5 non-null      float64
#  4   Z       5 non-null      float64
#  5   states  5 non-null      object
# dtypes: float64(5), object(1)
# memory usage: 452.0+ bytes

# %%
df.dtypes
# Out:
# V         float64
# W         float64
# X         float64
# Y         float64
# Z         float64
# states     object
# dtype: object

# %%
df.describe()
# Out:
#               V         W         X         Y         Z
# count  5.000000  5.000000  5.000000  5.000000  5.000000
# mean  -0.255437 -0.754133 -0.343834 -0.516302 -0.312048
# std    0.900342  0.827541  0.414114  0.850533  0.790327
# min   -1.642752 -1.905656 -0.760515 -1.682868 -1.165129
# 25%   -0.370753 -1.274144 -0.757391 -0.894117 -0.680210
# 50%   -0.351833 -0.416613 -0.333306 -0.628017 -0.602150
# 75%    0.452469 -0.350907  0.014855  0.256064 -0.008559
# max    0.635685  0.176655  0.117189  0.367429  0.895807

# %%
data = {'company':['Gcog','Gcog','mst','mst','det','det'],
        'Person':['samuel','samira','dary','ted','gane','klark'],
        'Sales':[12,4, 6, 7, 8,14]}

# %%
df2 = pd.DataFrame(data)
df2
# Out:
#   company  Person  Sales
# 0    Gcog  samuel     12
# 1    Gcog  samira      4
# 2     mst    dary      6
# 3     mst     ted      7
# 4     det    gane      8
# 5     det   klark     14

# %%
numeric_columns = df2.select_dtypes(include='number').columns
result = df2.groupby('company')[numeric_columns].mean()
result
# Out:
#          Sales
# company
# Gcog       8.0
# det       11.0
# mst        6.5

# %%
len(df2['Sales'].value_counts())
# Out:
# 6

# %%
df2['Sales'].unique()
# Out:
# array([12,  4,  6,  7,  8, 14])

# %%
df2["Sales"].nunique()
# Out:
# 6

# %%
df2['Sales'].value_counts()
# Out:
# Sales
# 12    1
# 4     1
# 6     1
# 7     1
# 8     1
# 14    1
# Name: count, dtype: int64

# %%
new_df = df2[(df2['Sales']>2) & (df2['Sales']==4)]
new_df
# Out:
#   company  Person  Sales
# 1    Gcog  samira      4

# %%
def times_two(number):
  return number * 2

# %%
df['new']=df2['Sales'].apply(times_two)

# %%
df
# Out:
#           V         W         X         Y         Z states  new
# A  0.635685 -1.274144 -0.760515  0.256064  0.895807     aw  NaN
# B  0.452469 -0.416613  0.014855 -1.682868 -0.680210     in  NaN
# C -1.642752 -0.350907 -0.757391 -0.894117 -0.602150    rus  NaN
# D -0.370753 -1.905656  0.117189  0.367429 -1.165129   chi,  NaN
# E -0.351833  0.176655 -0.333306 -0.628017 -0.008559   ussr  NaN

# %%
del df['new']

# %%
df
# Out:
#           V         W         X         Y         Z states
# A  0.635685 -1.274144 -0.760515  0.256064  0.895807     aw
# B  0.452469 -0.416613  0.014855 -1.682868 -0.680210     in
# C -1.642752 -0.350907 -0.757391 -0.894117 -0.602150    rus
# D -0.370753 -1.905656  0.117189  0.367429 -1.165129   chi,
# E -0.351833  0.176655 -0.333306 -0.628017 -0.008559   ussr

# %%
df.sort_values('V')
# Out:
#           V         W         X         Y         Z states
# C -1.642752 -0.350907 -0.757391 -0.894117 -0.602150    rus
# D -0.370753 -1.905656  0.117189  0.367429 -1.165129   chi,
# E -0.351833  0.176655 -0.333306 -0.628017 -0.008559   ussr
# B  0.452469 -0.416613  0.014855 -1.682868 -0.680210     in
# A  0.635685 -1.274144 -0.760515  0.256064  0.895807     aw
